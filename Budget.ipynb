# %%
import pandas as pd
import numpy as np

# %%
Budget = pd.read_excel(r'C:\Users\DELL\Desktop\p\Budget Sales data\Budget.xlsx', skiprows=3)

# %%
Budget.tail()
# Out:
#              Category Subcategory             ProductName  ProductKey  \
# 16           Clothing      Shorts  Men's Sports Shorts, S       445.0
# 17           Clothing       Socks  Mountain Bike Socks, M       218.0
# 18           Clothing       Vests         Classic Vest, S       471.0
# 19  SubTotal Clothing         NaN                     NaN         NaN
# 20        Grand Total         NaN                     NaN         NaN
#
#     Jan, 2016  Feb, 2016  Mar, 2016  Apr, 2016  May, 2016  Jun, 2016  \
# 16        421       5723       7301       6335       5288       6829
# 17         24        244        432        547        385        372
# 18        980       2008       1980       2312       2763       2591
# 19       6589      23652      27004      24787      25773      33091
# 20     871119     858350     999795    1131721    1226351    1713430
#
#     Jul, 2016  Aug, 2016  Sep, 2016  Oct, 2016  Nov, 2016  Dec, 2016  \
# ...

# %%
Budget.shape
# Out:
# (21, 17)

# %%
Budget.columns
# Out:
# Index(['Category', 'Subcategory', 'ProductName', 'ProductKey', 'Jan, 2016',
#        'Feb, 2016', 'Mar, 2016', 'Apr, 2016', 'May, 2016', 'Jun, 2016',
#        'Jul, 2016', 'Aug, 2016', 'Sep, 2016', 'Oct, 2016', 'Nov, 2016',
#        'Dec, 2016', 'Grand Total'],
#       dtype='object')

# %%
Budget.head(1)
# Out:
#       Category Subcategory          ProductName  ProductKey  Jan, 2016  \
# 0  Accessories  Bike Racks  Hitch Rack - 4-Bike       483.0       1131
#
#    Feb, 2016  Mar, 2016  Apr, 2016  May, 2016  Jun, 2016  Jul, 2016  \
# 0       2635       4134       2179       2637       3279       2218
#
#    Aug, 2016  Sep, 2016  Oct, 2016  Nov, 2016  Dec, 2016  Grand Total
# 0       3287       3885       2484       5441       3551        36861

# %%
Budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     21 non-null     object
#  1   Subcategory  17 non-null     object
#  2   ProductName  17 non-null     object
#  3   ProductKey   17 non-null     float64
#  4   Jan, 2016    21 non-null     int64
#  5   Feb, 2016    21 non-null     int64
#  6   Mar, 2016    21 non-null     int64
#  7   Apr, 2016    21 non-null     int64
#  8   May, 2016    21 non-null     int64
#  9   Jun, 2016    21 non-null     int64
#  10  Jul, 2016    21 non-null     int64
#  11  Aug, 2016    21 non-null     int64
#  12  Sep, 2016    21 non-null     int64
#  13  Oct, 2016    21 non-null     int64
#  14  Nov, 2016    21 non-null     int64
#  15  Dec, 2016    21 non-null     int64
#  16  Grand Total  21 non-null     int64
# dtypes: float64(1), int64(13), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# # Null values

# %%
Budget.isnull().sum()
# Out:
# Category       0
# Subcategory    4
# ProductName    4
# ProductKey     4
# Jan, 2016      0
# Feb, 2016      0
# Mar, 2016      0
# Apr, 2016      0
# May, 2016      0
# Jun, 2016      0
# Jul, 2016      0
# Aug, 2016      0
# Sep, 2016      0
# Oct, 2016      0
# Nov, 2016      0
# Dec, 2016      0
# Grand Total    0
# dtype: int64

# %%
Budget.isnull()
# Out:
#     Category  Subcategory  ProductName  ProductKey  Jan, 2016  Feb, 2016  \
# 0      False        False        False       False      False      False
# 1      False        False        False       False      False      False
# 2      False        False        False       False      False      False
# 3      False        False        False       False      False      False
# 4      False        False        False       False      False      False
# 5      False        False        False       False      False      False
# 6      False        False        False       False      False      False
# 7      False        False        False       False      False      False
# 8      False         True         True        True      False      False
# 9      False        False        False       False      False      False
# 10     False        False        False       False      False      False
# 11     False        False        False       False      False      False
# ...

# %%
Budget.head(3)
# Out:
#       Category        Subcategory             ProductName  ProductKey  \
# 0  Accessories         Bike Racks     Hitch Rack - 4-Bike       483.0
# 1  Accessories        Bike Stands  All-Purpose Bike Stand       486.0
# 2  Accessories  Bottles and Cages   Water Bottle - 30 oz.       477.0
#
#    Jan, 2016  Feb, 2016  Mar, 2016  Apr, 2016  May, 2016  Jun, 2016  \
# 0       1131       2635       4134       2179       2637       3279
# 1        666       3695       2868       4862       3439       4612
# 2       1892       4727       3656       4449       4051       6257
#
#    Jul, 2016  Aug, 2016  Sep, 2016  Oct, 2016  Nov, 2016  Dec, 2016  \
# 0       2218       3287       3885       2484       5441       3551
# 1       2774       3003       2401       4413       3881       2143
# 2       4871       5231       5461       5529       5220       6025
#
#    Grand Total
# 0        36861
# 1        38757
# 2        57369

# %% [markdown]
# # Data Cleaning

# %%
cover = Budget['Subcategory'].mode()[0]

# %%
Budget['Subcategory'].fillna(cover, inplace = True)

# %%
cover = Budget['ProductName'].mode()[0]

# %%
Budget['ProductName'].fillna(cover, inplace = True)

# %%
Pcover = Budget['ProductKey'].mean()

# %%
Budget['ProductKey'].fillna(Pcover, inplace = True)

# %%
Budget.isnull().sum()
# Out:
# Category       0
# Subcategory    0
# ProductName    0
# ProductKey     0
# Jan, 2016      0
# Feb, 2016      0
# Mar, 2016      0
# Apr, 2016      0
# May, 2016      0
# Jun, 2016      0
# Jul, 2016      0
# Aug, 2016      0
# Sep, 2016      0
# Oct, 2016      0
# Nov, 2016      0
# Dec, 2016      0
# Grand Total    0
# dtype: int64

# %%
Budget.describe()
# Out:
#        ProductKey      Jan, 2016      Feb, 2016      Mar, 2016     Apr, 2016  \
# count   21.000000      21.000000      21.000000      21.000000  2.100000e+01
# mean   403.117647  124445.571429  122621.428571  142827.857143  1.616744e+05
# std    106.329150  267512.184736  250523.231390  293679.499236  3.338041e+05
# min    212.000000      24.000000     244.000000     432.000000  5.470000e+02
# 25%    344.000000     666.000000    2635.000000    2868.000000  2.705000e+03
# 50%    445.000000    1892.000000    5723.000000    7301.000000  6.335000e+03
# 75%    483.000000   14499.000000   52447.000000   54596.000000  5.442800e+04
# max    560.000000  871119.000000  858350.000000  999795.000000  1.131721e+06
#
#           May, 2016     Jun, 2016     Jul, 2016     Aug, 2016     Sep, 2016  \
# count  2.100000e+01  2.100000e+01  2.100000e+01  2.100000e+01  2.100000e+01
# mean   1.751930e+05  2.447757e+05  1.935596e+05  2.253663e+05  2.153826e+05
# ...

# %% [markdown]
# # Droping Duplicates

# %%
Budget.drop_duplicates()
# Out:
#                 Category        Subcategory                 ProductName  \
# 0            Accessories         Bike Racks         Hitch Rack - 4-Bike
# 1            Accessories        Bike Stands      All-Purpose Bike Stand
# 2            Accessories  Bottles and Cages       Water Bottle - 30 oz.
# 3            Accessories           Cleaners       Bike Wash - Dissolver
# 4            Accessories            Fenders       Fender Set - Mountain
# 5            Accessories            Helmets       Sport-100 Helmet, Red
# 6            Accessories    Hydration Packs     Hydration Pack - 70 oz.
# 7            Accessories    Tires and Tubes         Patch Kit/8 Patches
# 8   SubTotal Accessories         Bike Racks                AWC Logo Cap
# 9                  Bikes     Mountain Bikes     Mountain-100 Silver, 38
# 10                 Bikes         Road Bikes            Road-150 Red, 62
# 11                 Bikes      Touring Bikes       Touring-2000 Blue, 60
# ...

# %%
Budget.to_csv('Budget.csv',index = False)
